# %%
from trustfids.utils.plot_poisoning import boxplot,plot_attack_success_rate
from trustfids.utils.stats_utils import  *

# %% [markdown]
# # Paper graph and values

# %% [markdown]
# ## Missrate comparison for multiple label fliping  rates.

# %%
plot_attack_success_rate(out_path="./figures/poisoning/asr_multiple_baselines.pdf", title="")

# %% [markdown]
# ## Accuracy and missrate as boxplots

# %% [markdown]
# ### Targeted

# %%
benign  = "./trustfids/benign/"
lone_loud = "./trustfids/lone/targeted/loud"
sybils_min_loud = "./trustfids/sybils_min/targeted/loud"
sybils_loud = "./trustfids/sybils/targeted/loud"
labels = ["Benign","Lone","Minority of\nbyzantine","Majority of\nbyzantine"]
ft_size = 13
boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, out_path="./figures/poisoning/trusfids_targeted_acc_all_distibutions.pdf", title="Targeted, accuracy.",labels= labels, font_size=ft_size ,zoom="high")
boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, out_path="./figures/poisoning/trusfids_targeted_missrate_all_distibutions.pdf", title="Targeted, miss rate.",labels= labels, font_size=ft_size ,metric="miss rate", zoom="low")
# Out:
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ### Untargeted

# %%
benign  = "./trustfids/benign/"
lone_loud = "./trustfids/lone/untargeted/loud"
sybils_min_loud = "./trustfids/sybils_min/untargeted/loud"
sybils_loud = "./trustfids/sybils/untargeted/loud"
labels = ["benign","lone","minority","majority"]

boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, out_path="./figures/poisoning/trusfids_untargeted_acc_all_distibutions.pdf", labels= labels,zoom="high")
boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, out_path="./figures/poisoning/trusfids_untargeted_missrate_all_distibutions.pdf",labels= labels,metric="missrate" ,zoom="low")
# Out:
# /home/leo/Workspace/imta/trust-fids/exps/trustfids/utils/plot_poisoning.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/leo/Workspace/imta/trust-fids/exps/trustfids/utils/plot_poisoning.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ## Accuracy and missrate

# %% [markdown]
# ### Trustfids

# %% [markdown]
# #### Targeted

# %%
benign = "../results/trustfids/benign/"
lone = "../results/trustfids/lone/targeted/loud"
byzantine_min = "../results/trustfids/sybils_min/targeted/loud"
byzantine_maj = "../results/trustfids/sybils/targeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(get_missrate_percent(r,"botiot", target="Reconnaissance"))
    print("\n")
# Out:
# ../results/trustfids/benign/
# Mean accuracy : 99.07081972793395 %
# ('Miss rate : 0.0%', 'Detection rate :100.0%')
#
#
# ../results/trustfids/lone/targeted/loud
# Mean accuracy : 99.0657285017685 %
# ('Miss rate : 0.0%', 'Detection rate :100.0%')
#
#
# ../results/trustfids/sybils_min/targeted/loud
# Mean accuracy : 98.9622306354867 %
# ('Miss rate : 0.00724952878062926%', 'Detection rate :99.99275047121937%')
#
#
# ../results/trustfids/sybils/targeted/loud
# Mean accuracy : 98.2835301396746 %
# ('Miss rate : 79.39683920545164%', 'Detection rate :20.60316079454835%')

# %% [markdown]
# #### Untargeted

# %%
benign = "../results/trustfids/benign/"
lone = "../results/trustfids/lone/untargeted/loud"
byzantine_min = "../results/trustfids/sybils_min/untargeted/loud"
byzantine_maj = "../results/trustfids/sybils/untargeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(f"Mean missrate : {get_mean_missrate(r)*100} %")
    print(f"Misclassification rate (in dataset): {(1-get_mean_accuracy(r, dataset='botiot'))*100} %")
    print("\n")
# Out:
# ../results/trustfids/benign/
# Mean accuracy : 99.07081972793395 %
# Mean missrate : 1.8277593103721765 %
# Misclassification rate (in dataset): 0.08899999999998354 %
#
#
# ../results/trustfids/lone/untargeted/loud
# Mean accuracy : 99.03244067142502 %
# Mean missrate : 2.0952592077739323 %
# Misclassification rate (in dataset): 0.08949999999999791 %
#
#
# ../results/trustfids/sybils_min/untargeted/loud
# Mean accuracy : 99.01666543681758 %
# Mean missrate : 1.9894084834198158 %
# Misclassification rate (in dataset): 0.10350000000000081 %
#
#
# ../results/trustfids/sybils/untargeted/loud
# Mean accuracy : 98.9304400438549 %
# Mean missrate : 2.1636855261022663 %
# Misclassification rate (in dataset): 0.08850000000000247 %

# %% [markdown]
# ###  Foolsfold

# %% [markdown]
# ### Targeted

# %%
benign = "../results/foolsgold/benign"
lone = "../results/foolsgold/lone/targeted/loud"
byzantine_min = "../results/foolsgold/sybils_min/targeted/loud"
byzantine_maj = "../results/foolsgold/sybils/targeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(get_missrate_percent(r,"botiot", target="Reconnaissance"))
    print(get_attack_success_rate(r,"botiot", target="Reconnaissance", benign_value=get_missrate(benign, "botiot", target="Reconnaissance")[0]))
    print("\n")
# Out:
# ../results/foolsgold/benign
# Mean accuracy : 55.44709016157328 %
# ('Miss rate : 5.1689140205886615%', 'Detection rate :94.83108597941133%')
# Attack success rate : 0.0%
#
#
# ../results/foolsgold/lone/targeted/loud
# Mean accuracy : 60.510801725068006 %
# ('Miss rate : 93.82340147890386%', 'Detection rate :6.176598521096128%')
# Attack success rate : 88.6544874583152%
#
#
# ../results/foolsgold/sybils_min/targeted/loud
# Mean accuracy : 54.645398140885135 %
# ('Miss rate : 2.9795563288386258%', 'Detection rate :97.02044367116137%')
# Attack success rate : -2.1893576917500357%
#
#
# ../results/foolsgold/sybils/targeted/loud
# Mean accuracy : 85.10435503262063 %
# ('Miss rate : 8.010729302595331%', 'Detection rate :91.98927069740466%')
# Attack success rate : 2.8418152820066704%

# %% [markdown]
# ### Untargeted

# %%
benign = "../results/foolsgold/benign"
lone = "../results/foolsgold/lone/untargeted/loud"
byzantine_min = "../results/foolsgold/sybils_min/untargeted/loud"
byzantine_maj = "../results/foolsgold/sybils/untargeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(f"Mean missrate : {get_mean_missrate(r)*100} %")
    print(f"Misclassification rate (in dataset): {(1-get_mean_accuracy(r, dataset='botiot'))*100} %")
    print("\n")
# Out:
# ../results/foolsgold/benign
# Mean accuracy : 55.44709016157328 %
# Mean missrate : 19.286950772830185 %
# Misclassification rate (in dataset): 0.3875000000000073 %
#
#
# ../results/foolsgold/lone/untargeted/loud
# Mean accuracy : 49.56893826821451 %
# Mean missrate : 72.29947332963714 %
# Misclassification rate (in dataset): 99.8955 %
#
#
# ../results/foolsgold/sybils_min/untargeted/loud
# Mean accuracy : 49.67025792772906 %
# Mean missrate : 17.579264839393847 %
# Misclassification rate (in dataset): 0.04549999999999832 %
#
#
# ../results/foolsgold/sybils/untargeted/loud
# Mean accuracy : 69.09213146687918 %
# Mean missrate : 68.2496246197583 %
# Misclassification rate (in dataset): 38.982000000000006 %

# %% [markdown]
# ### Fedavg

# %% [markdown]
# ### Targeted

# %%
benign = "../results/fedavg/benign"
lone = "../results/fedavg/lone/targeted/loud"
byzantine_min = "../results/fedavg/sybils_min/targeted/loud"
byzantine_maj = "../results/fedavg/sybils/targeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(get_missrate_percent(r,"botiot", target="Reconnaissance"))
    print(get_attack_success_rate(r,"botiot", target="Reconnaissance", benign_value=get_missrate(benign, "botiot", target="Reconnaissance")[0]))
    print("\n")
# Out:
# ../results/fedavg/benign
# Mean accuracy : 79.49844343293461 %
# ('Miss rate : 5.096418732782369%', 'Detection rate :94.90358126721763%')
# Attack success rate : 0.0%
#
#
# ../results/fedavg/lone/targeted/loud
# Mean accuracy : 83.63246903917654 %
# ('Miss rate : 6.734812237204582%', 'Detection rate :93.26518776279542%')
# Attack success rate : 1.6383935044222129%
#
#
# ../results/fedavg/sybils_min/targeted/loud
# Mean accuracy : 79.7269159058509 %
# ('Miss rate : 9.997100188487748%', 'Detection rate :90.00289981151225%')
# Attack success rate : 4.900681455705379%
#
#
# ../results/fedavg/sybils/targeted/loud
# Mean accuracy : 84.7251234223438 %
# ('Miss rate : 17.659852109612874%', 'Detection rate :82.34014789038713%')
# Attack success rate : 12.563433376830508%

# %% [markdown]
# ### Untargeted

# %%
benign = "../results/fedavg/benign"
lone = "../results/fedavg/lone/untargeted/loud"
byzantine_min = "../results/fedavg/sybils_min/untargeted/loud"
byzantine_maj = "../results/fedavg/sybils/untargeted/loud"
runs = [benign,lone,byzantine_min,byzantine_maj]
for r in runs: 
    print(r)
    print(f"Mean accuracy : {get_mean_accuracy(r)*100} %")
    print(f"Mean missrate : {get_mean_missrate(r)*100} %")
    print(f"Misclassification rate (in dataset): {(1-get_mean_accuracy(r, dataset='botiot'))*100} %")
    print("\n")
# Out:
# ../results/fedavg/benign
# Mean accuracy : 79.49844343293461 %
# Mean missrate : 51.91197862515791 %
# Misclassification rate (in dataset): 33.303000000000004 %
#
#
# ../results/fedavg/lone/untargeted/loud
# Mean accuracy : 78.38398560592346 %
# Mean missrate : 62.42212924211689 %
# Misclassification rate (in dataset): 54.7025 %
#
#
# ../results/fedavg/sybils_min/untargeted/loud
# Mean accuracy : 72.47815886960666 %
# Mean missrate : 57.7788733039059 %
# Misclassification rate (in dataset): 44.536500000000004 %
#
#
# ../results/fedavg/sybils/untargeted/loud
# Mean accuracy : 81.87293680410636 %
# Mean missrate : 60.620065151686894 %
# Misclassification rate (in dataset): 59.499 %

# %% [markdown]
# #### Single cluster federated learning.

# %%
botiot = "./trustfids/distributions/single cluster/benign/botiot"
cicids = "./trustfids/distributions/single cluster/benign/cicids"
nb15 = "./trustfids/distributions/single cluster/benign/nb15"
toniot = "./trustfids/distributions/single cluster/benign/toniot"

print(get_missrate_percent(botiot,"botiot", target="Reconnaissance"))
print(get_missrate_percent(toniot,"toniot", target="xss"))
print(get_missrate_percent(nb15,"nb15", target="Reconnaissance"))
print(get_missrate_percent(cicids,"cicids", target="Brute Force"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 nb15 = "./trustfids/distributions/single cluster/benign/nb15"
#       4 toniot = "./trustfids/distributions/single cluster/benign/toniot"
# ----> 6 print(get_missrate_percent(botiot,"botiot", target="Reconnaissance"))
#       7 print(get_missrate_percent(toniot,"toniot", target="xss"))
#       8 print(get_missrate_percent(nb15,"nb15", target="Reconnaissance"))
#
# File ~/trust-fids/exps/trustfids/utils/stats_utils.py:89, in get_missrate_percent(path, dataset, target, include_attacker)
#      75 def get_missrate_percent(
#      76     path: str, dataset: str, target: str = "", include_attacker: bool = False
#      77 ) -> Tuple[str, str]:
#      78     """_summary_
#      79     get_missrate_percent
#      80         Args:
#    (...)
#      87             Tuple[str, str]: _description_
# ...

# %% [markdown]
# ### Benign

# %%
trustfids = "./trustfids/scenario/benign/"
foolsgold = "./foolsgold/benign"
fedavg = "./fedavg/benign"
labels = ["trustfids","foolsgold","fedavg"]

boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Accuracy comparison of the baselines on single target poisonning")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")


boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Missrate comparison of the baselines on single target poisonning, attacker included",metric="missrate")
# Out:
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ### Targeted

# %%
trustfids = "../multirun/2023-09-08/09-15-13/+scenario_target=targeted,scenario_attacker=loud,scenario_distribution=lone"
foolsgold = "../multirun/2023-09-08/13-13-23/+scenario_target=targeted,archi=foolsgold,scenario_attacker=loud,scenario_distribution=lone"
fedavg = "../multirun/2023-09-08/13-13-23/+scenario_target=targeted,archi=fedavg,scenario_attacker=loud,scenario_distribution=lone"
labels = ["trustfids","foolsgold","fedavg"]
boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Accuracy comparison of the baselines on single target poisonning")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")


boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Missrate comparison of the baselines on single target poisonning, attacker included",metric="missrate")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       4 labels = ["trustfids","foolsgold","fedavg"]
#       5 # Prendre deux runs d'attaques un sur fedavg l'autre sur trustfids
# ----> 6 boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Accuracy comparison of the baselines on single target poisonning")
#       7 boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")
#      10 boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
#
# File ~/Workspace/imta/trust-fids/exps/trustfids/utils/plot_poisoning.py:53, in boxplot(title, out_path, include_attacker, metric, target, dataset, font_size, zoom, labels, *paths)
# ...

# %% [markdown]
# ## Untargeted

# %%
trustfids = "./trustfids/scenario/lone/untargeted/loud"
foolsgold = "./foolsgold/lone/untargeted/loud"
fedavg = "./foolsgold/lone/untargeted/loud"
labels = ["trustfids","foolsgold","fedavg"]
boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Accuracy comparison of the baselines on single target poisonning")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")


boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Missrate comparison of the baselines on single target poisonning, attacker included",metric="missrate")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 labels = ["trustfids","foolsgold","fedavg"]
#       5 # Prendre deux runs d'attaques un sur fedavg l'autre sur trustfids
# ----> 6 boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Accuracy comparison of the baselines on single target poisonning")
#       7 boxplot(trustfids,foolsgold,fedavg, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")
#      10 boxplot(trustfids,foolsgold,fedavg, labels=labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
#
# File ~/trust-fids/exps/trustfids/utils/plot_poisoning.py:50, in boxplot(title, out_path, include_attacker, metric, target, dataset, labels, *paths)
#      46     mustaches: List[List[float]] = [
# ...

# %% [markdown]
# ## Lone, targeted, comparison of the different trustfids baselines.

# %%
trustfids_benign  = "./trustfids/scenario/benign/"
trustfids_loud = "./trustfids/scenario/lone/targeted/loud"
trustfids_increment = "./trustfids/scenario/lone/targeted/increment"
trustfids_decrement = "./trustfids/scenario/lone/targeted/decrement"
trustfids_redemption = "./trustfids/scenario/lone/targeted/redemption"
trustfids_stealth = "./trustfids/scenario/lone/targeted/stealth"

labels = ["benign", "loud","increment"]
boxplot(trustfids_benign,trustfids_loud,trustfids_increment, labels= labels, title="Accuracy comparison of the baselines on single target poisonning")
boxplot(trustfids_benign,trustfids_loud,trustfids_increment, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")


boxplot(trustfids_benign,trustfids_loud,trustfids_increment, labels= labels, title="Accuracy comparison of the baselines on single target poisonning", metric="missrate")
boxplot(trustfids_benign,trustfids_loud,trustfids_increment, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included", metric="missrate")
# Out:
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ## Lone vs sybils vs sybils vs sybils_min

# %%
benign  = "./trustfids/scenario/benign/"
lone_loud = "./trustfids/scenario/lone/targeted/loud"
sybils_min_loud = "./trustfids/scenario/sybils_min/targeted/loud"
sybils_loud = "./trustfids/scenario/sybils/targeted/loud"
labels = ["benign","lone","sybils_min","sybils"]
boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, labels= labels, title="Accuracy comparison of the baselines on single target poisonning")

boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, labels=labels, include_attacker=True, title="Accuracy comparison of the baselines on single target poisonning, attacker included")


boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, labels= labels, title="Missrate comparison of the baselines on single target poisonning",metric="missrate")
boxplot(benign,lone_loud, sybils_min_loud, sybils_loud, labels=labels, include_attacker=True, title="Missrate comparison of the baselines on single target poisonning, attacker included",metric="missrate")
# Out:
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ## Strip random label.

# %%
benign   = "./trustfids/scenario/benign/"
benign_striped = "../outputs/2023-09-25/14-57-46"
targeted_non_striped = "./trustfids/sybils_min/targeted/loud" 
targeted_striped = "../outputs/2023-09-26/10-40-25"
labels = ["targeted","targeted_striped", "benign", "benign_striped"]
boxplot(targeted_non_striped, targeted_striped, benign, benign_striped, labels= labels, title="Accuracy comparison on single target poisonning, striped mean that a random class is removed on each participants")

boxplot(targeted_non_striped, targeted_striped, benign, benign_striped,  labels= labels, title="Missrate comparison on single target poisonning, striped mean that a random class is removed on each participants",metric="missrate")
# Out:
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:51: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ### Analysis of single cluster

# %%
trustfids   =  "../multirun/2023-09-27/12-26-12/+scenario_target=targeted,archi=trustfids,scenario_attacker=loud,scenario_distribution=single_cluster"
foolsgold = "../multirun/2023-09-27/12-26-12/+scenario_target=targeted,archi=foolsgold,scenario_attacker=loud,scenario_distribution=single_cluster"
fedavg = "../outputs/2023-09-27/13-48-57"

labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'botiot', 'Reconnaissance')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='Reconnaissance', dataset='botiot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 0.2972306800057996%', 'Detection rate :99.7027693199942%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 2.4406746894785174%', 'Detection rate :97.55932531052149%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 55.712628679135854%', 'Detection rate :44.287371320864146%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 0.2972306800057996%', 'Detection rate :99.7027693199942%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 21.445556038857475%', 'Detection rate :78.55444396114252%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ### Sybils_min on a single cluster

# %%
trustfids = "../multirun/2023-09-27/19-49-50/+scenario_target=targeted,archi=trustfids,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster"
foolsgold = "../multirun/2023-09-27/19-49-50/+scenario_target=targeted,archi=foolsgold,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster"
fedavg = "../multirun/2023-09-27/19-49-50/+scenario_target=targeted,archi=fedavg,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster"

labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'botiot', 'Reconnaissance')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='Reconnaissance', dataset='botiot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 0.420472669276497%', 'Detection rate :99.57952733072351%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 61.81794016722246%', 'Detection rate :38.18205983277754%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 55.6981296215746%', 'Detection rate :44.3018703784254%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 0.420472669276497%', 'Detection rate :99.57952733072351%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 67.32999855009425%', 'Detection rate :32.670001449905754%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ### Sybils on a single cluster / 1 random class is dropped

# %%
trustfids = "../multirun/2023-09-27/19-35-08/+scenario_target=targeted,archi=trustfids,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"
foolsgold = "../multirun/2023-09-27/19-35-08/+scenario_target=targeted,archi=foolsgold,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"
fedavg = "../multirun/2023-09-27/19-35-08/+scenario_target=targeted,archi=fedavg,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"

labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'botiot', 'Reconnaissance')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='Reconnaissance', dataset='botiot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 0.15224010439321445%', 'Detection rate :99.84775989560679%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 66.56517326373785%', 'Detection rate :33.43482673626214%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 62.60693054951428%', 'Detection rate :37.39306945048572%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 0.15224010439321445%', 'Detection rate :99.84775989560679%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 84.62519936204147%', 'Detection rate :15.374800637958533%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ### Sybils min single cluster, no class dropped (almost IID)

# %%
fedavg = "../multirun/2023-09-28/17-40-14/+scenario_target=targeted,archi=fedavg,fl.drop_class=False,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"
foolsgold = "../multirun/2023-09-28/17-40-14/+scenario_target=targeted,archi=foolsgold,fl.drop_class=False,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"
trustfids = "../multirun/2023-09-28/17-40-14/+scenario_target=targeted,archi=trustfids,fl.drop_class=False,scenario_attacker=loud,scenario_distribution=sybils_single_cluster"

labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'botiot', 'Reconnaissance')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'botiot', 'Reconnaissance')}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'botiot', 'Reconnaissance')}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='Reconnaissance', dataset='botiot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 0.06524575902566333%', 'Detection rate :99.93475424097433%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 0.07974481658692185%', 'Detection rate :99.92025518341308%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 55.68363056401334%', 'Detection rate :44.316369435986665%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 0.06524575902566333%', 'Detection rate :99.93475424097433%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 0.07974481658692185%', 'Detection rate :99.92025518341308%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# ...

# %% [markdown]
# ### Toniot

# %%
trustfids = "../multirun/2023-09-27/22-27-15/+scenario_target=targeted_xss,archi=trustfids,fl.drop_class_nb=2,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster_toniot"
foolsgold = "../multirun/2023-09-27/22-27-15/+scenario_target=targeted_xss,archi=foolsgold,fl.drop_class_nb=2,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster_toniot"
fedavg = "../multirun/2023-09-27/22-27-15/+scenario_target=targeted_xss,archi=fedavg,fl.drop_class_nb=2,scenario_attacker=loud,scenario_distribution=sybils_min_single_cluster_toniot"


labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'toniot', 'xss')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='xss', dataset='toniot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 2.292835748958584%', 'Detection rate :97.7071642510414%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 1.1791234895169898%', 'Detection rate :98.82087651048302%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 6.15554101972665%', 'Detection rate :93.84445898027334%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 2.292835748958584%', 'Detection rate :97.7071642510414%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 37.967087823183114%', 'Detection rate :62.03291217681688%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# ## Single cluster pathological non-IID

# %%
trustfids = "../multirun/2023-09-29/12-05-10/archi=trustfids,scenario_distribution=targeted_non_iid_single_cluster.yaml"
foolsgold = "../multirun/2023-09-29/12-05-10/archi=foolsgold,scenario_distribution=targeted_non_iid_single_cluster.yaml"
fedavg = "../multirun/2023-09-29/12-05-10/archi=fedavg,scenario_distribution=targeted_non_iid_single_cluster.yaml"


labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'toniot', 'xss')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='xss', dataset='toniot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 100.0%', 'Detection rate :0.0%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 65.46554817288455%', 'Detection rate :34.53445182711544%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 100.0%', 'Detection rate :0.0%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 100.0%', 'Detection rate :0.0%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 76.05339886814738%', 'Detection rate :23.94660113185262%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# ...

# %%
trustfids = "../multirun/2023-09-29/17-02-21/archi=trustfids,scenario_distribution=targeted_non_iid_single_cluster"
foolsgold = "../multirun/2023-09-29/17-02-21/archi=foolsgold,scenario_distribution=targeted_non_iid_single_cluster"
fedavg = "../multirun/2023-09-29/17-02-21/archi=fedavg,scenario_distribution=targeted_non_iid_single_cluster"


labels = ["trustfids","foolsglod","fedavg"]
print(f"Foolsgold, mean missrate on targeted task (without attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss')}")
print(f"Trustfids, mean missrate on targeted task (without attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss')}")
print(f"Fedavg, mean missrate on targeted task (without attacker) :  {get_missrate_percent(fedavg,'toniot', 'xss')}")

print(f"Foolsgold, mean missrate on targeted task (with attacker) : {get_missrate_percent(foolsgold,'toniot', 'xss',include_attacker=True)}")
print(f"Trustfids, mean missrate on targeted task (with attacker) :  {get_missrate_percent(trustfids,'toniot', 'xss',include_attacker=True)}")

boxplot(trustfids, foolsgold, fedavg,labels= labels, title="Global accuracy comparison, single dataset and single target poisonning")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Global missrate comparison, single dataset and single target poisonning",metric="missrate")
boxplot(trustfids, foolsgold, fedavg, labels= labels, title="Targeted missrate comparison, single dataset and single target poisonning",metric="missrate",target='xss', dataset='toniot' )
# Out:
# Foolsgold, mean missrate on targeted task (without attacker) : ('Miss rate : 0.6231280338761318%', 'Detection rate :99.37687196612387%')
# Trustfids, mean missrate on targeted task (without attacker) :  ('Miss rate : 0.6998509804307305%', 'Detection rate :99.30014901956928%')
# Fedavg, mean missrate on targeted task (without attacker) :  ('Miss rate : 2.723172788928289%', 'Detection rate :97.27682721107172%')
# Foolsgold, mean missrate on targeted task (with attacker) : ('Miss rate : 0.6231280338761318%', 'Detection rate :99.37687196612387%')
# Trustfids, mean missrate on targeted task (with attacker) :  ('Miss rate : 40.217291516048704%', 'Detection rate :59.782708483951296%')
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:65: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# /home/pm/trust-fids/exps/trustfids/utils/plot_poisoning.py:65: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...
